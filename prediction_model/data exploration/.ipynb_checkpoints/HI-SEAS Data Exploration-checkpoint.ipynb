# %%
import pandas as pd

DATA_PATH = '../hi-seas-data'
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-a05b7d8f566c> in <module>()
# ----> 1 import pandas as pd
#       2
#       3 DATA_PATH = '../hi-seas-data'
#       4
#
# ImportError: No module named 'pandas'
