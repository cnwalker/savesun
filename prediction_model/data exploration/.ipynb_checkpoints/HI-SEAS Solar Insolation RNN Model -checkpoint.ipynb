# %% [markdown]
# # HI-SEAS Solar Insolation RNN Model
#
# Author: Abhipray Sahoo
# Date: 04/30/2017

# %% [markdown]
# ### Goal:
# Estimate the solar radiation incident on the ground at HI-SEAS in order to predict power generated by solar panels. The model should be able to give best estimate for the solar radiation given meterological conditions.
#
# ### Dataset:
# A - NASA's HI-SEAS meterological data and solar irradiance.
#
# B - Additional climate data from Dark Sky API for the same dates as A
#
# Uncomment cells to re-activate

# %% [markdown]
# ## Load NASA dataset

# %%
# %matplotlib inline

import os
import pandas as pd
import numpy as np
import seaborn as sns

DATA_PATH = '../hi-seas-data'

X_aug = pd.read_pickle('nasa_forecast_combined.pkl')

# %%
# Drop any nans 
X_aug = X_aug.dropna()
X_aug.describe()
# Out:
#            id   unix_secs        date      time  irradiance     speed  \
# count   32007       32007       32007     32007    32007.00  32007.00
# unique  32007       32007         120      8181    14111.00     37.00
# top     33132  1478754303  2016-11-07  16:20:18        1.22      5.62
# freq        1           1         288        24     2199.00   4567.00
#
#         humidity  temperature  direction    pressure  humidity_fc  \
# count   32007.00      32007.0   32007.00  32007.0000     32007.00
# unique     94.00         38.0   17668.00     37.0000        68.00
# top         1.01         45.0       0.11    749.3146         0.82
# freq     1959.00       2801.0      93.00   4567.0000      1174.00
#
#         windSpeed_fc  windBearing_fc  precipIntensity_fc  \
# count        32007.0           32007             32007.0
# unique         848.0             356               173.0
# top              2.6             153                 0.0
# freq           161.0             333             22866.0
#
#         precipProbability_fc  pressure_fc  visibility_fc  cloudCover_fc
# count                32007.0      32007.0        32007.0       32007.00
# unique                  69.0        779.0          200.0          67.00
# top                      0.0       1015.5           10.0           0.31
# freq                 22866.0        178.0        22626.0        6648.00

# %% [markdown]
# ## Train small Fully Connected Network
#
# 1. Per feature scaling between min max
# 2. Train a fully connected network

# %%
from sklearn.svm import SVR
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

tmp = X_aug.dropna()
print(tmp.shape)
y = np.array(tmp['irradiance'])
X = np.array(tmp.drop(['irradiance', 'date', 'unix_secs', 'id', 'time'], 1)).astype(np.float)
# X = np.array(tmp[['temperature', 'direction', 'cloudCover_fc']]).astype(np.float)

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=9)
# Out:
# (32007, 18)

# %%
from keras.models import Sequential
from keras.layers import Dense, Input, Dropout
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=20, verbose=0, mode='auto')

model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(X.shape[1], )))
model.add(Dense(1024, activation='relu', input_shape=(X.shape[1], )))
model.add(Dropout(0.2))
model.add(Dense(1, activation='relu'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])
model.fit(X_scaled, y, validation_split=0.1, shuffle=True, batch_size=32, epochs=1000,
         callbacks=[early_stopping])
# Out:
# Train on 28806 samples, validate on 3201 samples
# Epoch 1/1000
# 28806/28806 [==============================] - 2s - loss: 97826.0772 - mean_squared_error: 97826.0772 - val_loss: 23438.7919 - val_mean_squared_error: 23438.7919
# Epoch 2/1000
# 28806/28806 [==============================] - 2s - loss: 53317.5839 - mean_squared_error: 53317.5839 - val_loss: 21224.7903 - val_mean_squared_error: 21224.7903
# Epoch 3/1000
# 28806/28806 [==============================] - 2s - loss: 43507.2999 - mean_squared_error: 43507.2999 - val_loss: 20758.9200 - val_mean_squared_error: 20758.9200
# Epoch 4/1000
# 28806/28806 [==============================] - 2s - loss: 39903.8394 - mean_squared_error: 39903.8394 - val_loss: 20348.6598 - val_mean_squared_error: 20348.6598
# Epoch 5/1000
# 28806/28806 [==============================] - 2s - loss: 38026.5869 - mean_squared_error: 38026.5869 - val_loss: 21340.9824 - val_mean_squared_error: 21340.9824
# Epoch 6/1000
# 28806/28806 [==============================] - 2s - loss: 36801.1774 - mean_squared_error: 36801.1774 - val_loss: 21640.4721 - val_mean_squared_error: 21640.4721
# Epoch 7/1000
# 28806/28806 [==============================] - 2s - loss: 35888.9363 - mean_squared_error: 35888.9363 - val_loss: 23275.3096 - val_mean_squared_error: 23275.3096
# Epoch 8/1000
# 28806/28806 [==============================] - 2s - loss: 35196.1136 - mean_squared_error: 35196.1136 - val_loss: 23361.7402 - val_mean_squared_error: 23361.7402
# Epoch 9/1000
# 28806/28806 [==============================] - 2s - loss: 34698.1919 - mean_squared_error: 34698.1919 - val_loss: 21504.8466 - val_mean_squared_error: 21504.8466
# Epoch 10/1000
# 28806/28806 [==============================] - 2s - loss: 34167.4549 - mean_squared_error: 34167.4549 - val_loss: 24825.9718 - val_mean_squared_error: 24825.9718
# Epoch 11/1000
# 28806/28806 [==============================] - 2s - loss: 33617.9759 - mean_squared_error: 33617.9759 - val_loss: 24203.3337 - val_mean_squared_error: 24203.3337
# Epoch 12/1000
# 28806/28806 [==============================] - 2s - loss: 33313.7446 - mean_squared_error: 33313.7446 - val_loss: 24772.5852 - val_mean_squared_error: 24772.5852
# Epoch 13/1000
# 28806/28806 [==============================] - 2s - loss: 32954.0216 - mean_squared_error: 32954.0216 - val_loss: 24600.7940 - val_mean_squared_error: 24600.7940
# Epoch 14/1000
# 28806/28806 [==============================] - 2s - loss: 32586.2805 - mean_squared_error: 32586.2805 - val_loss: 24492.9901 - val_mean_squared_error: 24492.9901
# Epoch 15/1000
# 28806/28806 [==============================] - 2s - loss: 32237.4395 - mean_squared_error: 32237.4395 - val_loss: 24583.4529 - val_mean_squared_error: 24583.4529
# Epoch 16/1000
# 28806/28806 [==============================] - 2s - loss: 31983.2969 - mean_squared_error: 31983.2969 - val_loss: 24555.3393 - val_mean_squared_error: 24555.3393
# Epoch 17/1000
# 28806/28806 [==============================] - 2s - loss: 31583.9428 - mean_squared_error: 31583.9428 - val_loss: 25317.9708 - val_mean_squared_error: 25317.9708
# Epoch 18/1000
# 28806/28806 [==============================] - 2s - loss: 31450.0167 - mean_squared_error: 31450.0167 - val_loss: 24293.9346 - val_mean_squared_error: 24293.9346
# Epoch 19/1000
# 28806/28806 [==============================] - 2s - loss: 31265.7840 - mean_squared_error: 31265.7840 - val_loss: 24733.0338 - val_mean_squared_error: 24733.0338
# Epoch 20/1000
# 28806/28806 [==============================] - 2s - loss: 31044.5478 - mean_squared_error: 31044.5478 - val_loss: 23475.4490 - val_mean_squared_error: 23475.4490
# Epoch 21/1000
# 28806/28806 [==============================] - 2s - loss: 30786.9621 - mean_squared_error: 30786.9621 - val_loss: 23603.6176 - val_mean_squared_error: 23603.6176
# Epoch 22/1000
# 28806/28806 [==============================] - 2s - loss: 30695.7184 - mean_squared_error: 30695.7184 - val_loss: 23505.5465 - val_mean_squared_error: 23505.5465
# Epoch 23/1000
# 28806/28806 [==============================] - 2s - loss: 30513.0829 - mean_squared_error: 30513.0829 - val_loss: 23711.4696 - val_mean_squared_error: 23711.4696
# Epoch 24/1000
# 28806/28806 [==============================] - 2s - loss: 30436.5616 - mean_squared_error: 30436.5616 - val_loss: 22753.7045 - val_mean_squared_error: 22753.7045
# Epoch 25/1000
# 28806/28806 [==============================] - 3s - loss: 30361.0859 - mean_squared_error: 30361.0859 - val_loss: 23283.1498 - val_mean_squared_error: 23283.1498

# %%
model.evaluate(X_test, y_test)
# Out:
# 7296/8002 [==========================>...] - ETA: 0s
# [29994.166870391779, 29994.166870391779]

# %%
print(model.predict(X_train[0][None,:]))
print(y[0])
# Out:
# [[ 0.]]
# 1.27

# %%
# Five random example predictions
n_examples = 15
for i in range(n_examples):
    idx = np.random.randint(X_test.shape[0])
    ex_pred = model.predict(X_test[idx][None, :])[0]
    expected = y_test[idx]
    print("[{}] [{}] Predicted: {} Expected: {}".format(i, idx, ex_pred, expected))
# Out:
# [0] [7900] Predicted: [ 622.67474365] Expected: 862.66
# [1] [3128] Predicted: [ 0.] Expected: 1.24
# [2] [1385] Predicted: [ 366.76721191] Expected: 98.76
# [3] [6393] Predicted: [ 689.703125] Expected: 792.96
# [4] [4265] Predicted: [ 141.3946991] Expected: 312.47
# [5] [3877] Predicted: [ 17.78536415] Expected: 1.21
# [6] [2566] Predicted: [ 182.32449341] Expected: 170.04
# [7] [584] Predicted: [ 671.10797119] Expected: 588.05
# [8] [7546] Predicted: [ 0.] Expected: 1.23
# [9] [5879] Predicted: [ 660.17358398] Expected: 201.05
# [10] [3819] Predicted: [ 513.12811279] Expected: 365.58
# [11] [6030] Predicted: [ 0.] Expected: 1.24
# [12] [1138] Predicted: [ 841.75317383] Expected: 556.59
# [13] [884] Predicted: [ 0.] Expected: 1.24
# [14] [4451] Predicted: [ 135.06750488] Expected: 1.99

# %% [markdown]
# ## Model the Time Series using RNN

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)
